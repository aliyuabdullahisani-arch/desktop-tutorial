# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
message = "Hello, World!"
print(message)
# Out:
# Hello, World!

# %%
moisture_content = 40  # in percentage
print("The Moisture Content of this soil is", moisture_content)
# Out:
# The Moisture Content of this soil is 40

# %%
age = 25  # in years
print("My age is", age, "years")
# Out:
# My age is 25 years

# %%
a = "1234"
b = "5678"
print(a + b)
# Out:
# 12345678

# %%
name = "aliyu"
print(name)
# Out:
# aliyu
