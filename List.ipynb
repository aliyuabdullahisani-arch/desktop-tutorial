# %%
family = ["Mom", "Dad", "Zainab", "Bilkisu", "Aminu", "Umar","Aliyu", "Abubakar", "Umma", "Hafsatu", "Hauwa", "maryam", "abdullah"]

# %%
male_members = {"Dad","Aminu","Umar","Aliyu","Abubakar","Abdul"}
female_member = {"Mom","Zainab","Bilkisu","Umma","Hafsa","Hauwa"}
print(male_members)
# Out:
# {'Aminu', 'Dad', 'Abubakar', 'Umar', 'Aliyu', 'Abdul'}

# %%
print(female_member)
# Out:
# {'Zainab', 'Umma', 'Bilkisu', 'Mom', 'Hafsa', 'Hauwa'}

# %%
print(family)
# Out:
# ['Mom', 'Dad', 'Zainab', 'Bilkisu', 'Aminu', 'Umar', 'Aliyu', 'Abubakar', 'Umma', 'Hafsatu', 'Hauwa', 'maryam', 'abdullah']

# %%
a = 3
b = 10
c = a + b
print(c)
# Out:
# 13

# %%
a = 5
b = 10
print(a + b)
# Out:
# 15

# %%
fruits = ["mango", "banana", "grape", "berries", "strawberry", "lemon"]
print(fruits)
# Out:
# ['mango', 'banana', 'grape', 'berries', 'strawberry', 'lemon']

# %%
bicycles = ["trek", "cannodale", "redline", "specialized"]
print(bicycles)
# Out:
# ['trek', 'cannodale', 'redline', 'specialized']

# %%
personal_list = ["mango", "24", "3.14", True, "banana"]
print(personal_list)
# Out:
# ['mango', '24', '3.14', True, 'banana']

# %% [markdown]
# indexing

# %%
print("The item in index 3 is;", personal_list[3])
# Out:
# The item in index 3 is; True

# %%
print("The last fruit is;",personal_list[4])
# Out:
# The last fruit is; banana

# %% [markdown]
# Accessing elelemts in a list

# %%
name = ["kabir", "umar", "abubakar", "ali"]
print(name[3].strip().title())
# Out:
# Ali

# %%
print("The second name is;", name[1].title())
# Out:
# The second name is; Umar

# %%
print("The third name is;", name[2].title())
# Out:
# The third name is; Abubakar

# %%
print("The second name and third name are",name[1] + " " + "and " + name[2]  + " respectively")
# Out:
# The second name and third name are umar and abubakar respectively

# %%
foods = ("rice","miller", "wheat", "maize")
print("The last item in the list is;", foods[-1].title())
print("The first item in the list is;", foods[-4].title())
# Out:
# The last item in the list is; Maize
# The first item in the list is; Rice

# %%
print("The second item in the list is;", foods[-3].title())
# Out:
# The second item in the list is; Miller

# %%
bicycles
# Out:
# ['trek', 'cannodale', 'redline', 'specialized']

# %%
change = bicycles
print("my first change is;", change[2])
# Out:
# my first change is; redline

# %% [markdown]
# changing, Adding, and Removing Elements

# %%
my_list = ["a"]
print(my_list)
# Out:
# ['a']

# %%
my_list[0] = "b"
print(my_list)
# Out:
# ['b']

# %%
motorcycles = ["honda","yamaha","suzuki"]
print("original motorcycles:", motorcycles)
# Out:
# original motorcycles: ['honda', 'yamaha', 'suzuki']

# %%
motorcycles[1] = "ducati"
print("updated motorcycles:", motorcycles)
# Out:
# updated motorcycles: ['honda', 'ducati', 'suzuki']

# %%
my_list
my_list.append("c")
print(my_list)
# Out:
# ['b', 'c']

# %%
name = ["kabir", "umar", "abubakar", "ali"]
name.append("musa")
print(name)
# Out:
# ['kabir', 'umar', 'abubakar', 'ali', 'musa']

# %%
attendance = []
attendance.append("sani")
attendance.append("auwal") 
attendance.append("kamal")
print(attendance)
# Out:
# ['sani', 'auwal', 'kamal']

# %% [markdown]
# inserting elements in a list (.insert(index, value))

# %%
alpha = ["a", "b", "d", "e"]
alpha.insert(2,"c")
print(alpha)
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
num = list(range(1,5))
print(num)
# Out:
# [1, 2, 3, 4]

# %%
num.insert(4,5)
print(num)
# Out:
# [1, 2, 3, 4, 5]

# %%
courses = ["soil", "concrete", "steel", "geotech"]
courses.append("hydrology")
print(courses)
# Out:
# ['soil', 'concrete', 'steel', 'geotech', 'hydrology']

# %%
courses.insert(2, "statistics") 
print(courses)
# Out:
# ['soil', 'concrete', 'statistics', 'steel', 'geotech', 'hydrology', 'hydrology']

# %%
my_favourite = "enineering  mathematics"
courses.insert(1, my_favourite)
print(courses)
# Out:
# ['soil', 'enineering  mathematics', 'concrete', 'statistics', 'steel', 'geotech', 'hydrology', 'hydrology']

# %%
del courses[7]
print(courses)
# Out:
# ['soil', 'enineering  mathematics', 'concrete', 'statistics', 'steel', 'geotech', 'hydrology']

# %%
del courses[-7]
print(courses)
# Out:
# ['enineering  mathematics', 'concrete', 'statistics', 'steel', 'geotech', 'hydrology']

# %%
fruits = ["mango", "banana", "grape", "berries", "strawberry", "lemon"]
print(fruits.pop())
# Out:
# lemon

# %%
print(fruits)
# Out:
# ['mango', 'banana', 'grape', 'berries', 'strawberry']

# %%
popped_fruit = fruits.pop()
print(fruits)
# Out:
# ['mango', 'banana', 'grape', 'berries']

# %%
courses = ["math","physics", "chemistry",]
removed_course = courses.pop()
print("The removed course is:", removed_course)
print(courses)
# Out:
# The removed course is: chemistry
# ['math', 'physics']

# %%
courses = ["soil", "concrete", "steel", "geotech"]
popped_course = courses.pop(1)
print("The popped_course is:", popped_course.title())
# Out:
# The popped_course is: Concrete

# %%
elements = ["hydrogen", "helium", "polymer", "carbon", "oxygen"]
print(elements)
# Out:
# ['hydrogen', 'helium', 'polymer', 'carbon', 'oxygen']

# %%
elements.remove("polymer")
print(elements)
# Out:
# ['hydrogen', 'helium', 'carbon', 'oxygen']

# %% [markdown]
# .sort() and .sorted() method

# %%
nums = [2,4,5,6,1,3]
nums.sort()
print(nums)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
nums
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
nums.sort(reverse=True)
print(nums)
# Out:
# [6, 5, 4, 3, 2, 1]

# %%
social_media = ["facebook", "twitter", "instagram", "whatsapp", "telegram"]
print("social media:" , social_media)
social_media.sort()
print("sorted social media:",social_media)
# Out:
# social media: ['facebook', 'twitter', 'instagram', 'whatsapp', 'telegram']
# sorted social media: ['facebook', 'instagram', 'telegram', 'twitter', 'whatsapp']

# %%
social_media
# Out:
# ['facebook', 'instagram', 'telegram', 'twitter', 'whatsapp']

# %%
cars = ["chevrolete", "audi", "toyota", "marcedes"]
print("This is the original list:", cars )

cars.sort(reverse=True)
print("This is sorted list in reversed order:", cars)
# Out:
# This is the original list: ['chevrolete', 'audi', 'toyota', 'marcedes']
# This is sorted list in reversed order: ['toyota', 'marcedes', 'chevrolete', 'audi']

# %% [markdown]
# SORTED

# %%
alpha = "d", "e", "a", "b", "c"
print("The original list:", alpha)
print("The temporarily sorted list is:",sorted(alpha))
# Out:
# The original list: ('d', 'e', 'a', 'b', 'c')
# The temporarily sorted list is: ['a', 'b', 'c', 'd', 'e']

# %%
alpha
# Out:
# ('d', 'e', 'a', 'b', 'c')

# %% [markdown]
# number of element in list len()

# %%
print("The lenths of alpha is:", len(alpha))
print("The exact number of fruits is;", len(fruits))
# Out:
# The lenths of alpha is: 5
# The exact number of fruits is; 4

# %%
print("Actual number of cars is:", len(cars))
# Out:
# Actual number of cars is: 4

# %%
print("The total number of the family members are:", len(family))
# Out:
# The total number of the family members are: 13
