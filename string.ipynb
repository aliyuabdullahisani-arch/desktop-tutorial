# %%
name = "John"
print(name.capitalize())
# Out:
# John

# %%
name = "kabir"
print(name.upper())
# Out:
# KABIR

# %%
name = "KABIR"
print(name.lower())
# Out:
# kabir

# %%
name_1 = "aliyu"
name_2 = "abdullahi"
print(name_1.title(), name_2.title())
# Out:
# Aliyu Abdullahi

# %% [markdown]
# Aliyu Abdullahi is a programming
# #  heading 1
# ## heading 2

# %%
a = "aliyu"
print(a.title())
# Out:
# Aliyu

# %%
name = "aliyu"
print(name)
# Out:
# aliyu

# %%
name = "aliyu"
print(name.strip().title())
# Out:
# Aliyu

# %%
first_name = "aliyu"
last_name = "abdullahi"
full_name = first_name + " " + last_name
print(full_name)
# Out:
# aliyu abdullahi

# %%
name = "athiru"
print(name.replace("t", "s").strip().title())
# Out:
# Ashiru

# %%
list = "abc"
print(list.rsplit(" "))
# Out:
# ['abc']

# %%
a = "A B C"
print(a.split(" "))
# Out:
# ['A', 'B', 'C']

# %%
A = "hello"
print(A.find("e"))
# Out:
# 1

# %%
print(A.find("o"))
# Out:
# 4

# %%
b = "banana"
print(b.count("a"))
# Out:
# 3
